# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sunspot = pd.read_csv("monthly.csv")

# %%
sunspot
# Out:
#      Year  Month     Ra
# 0    1944     12   31.2
# 1    1945      1   18.5
# 2    1945      2   11.8
# 3    1945      3   19.7
# 4    1945      4   31.6
# ..    ...    ...    ...
# 949  2024      1  102.8
# 950  2024      2   94.8
# 951  2024      3   84.8
# 952  2024      4  107.1
# 953  2024      5  120.5
#
# [954 rows x 3 columns]

# %%
# 6. Yearly Average Sunspots (Trend Analysis)
yearly_avg = sunspot.groupby('Year')['Ra'].mean()
# Font settings
label_fontsize = 14
title_fontsize = 16
axis_fontweight = 'bold'
ticks_fontsize = 12  # Font size for x and y axis ticks
plt.figure(figsize=(12, 6))
sns.lineplot(x=yearly_avg.index, y=yearly_avg.values, marker="o", color='black')
plt.title("Average Sunspot Numbers by Year", fontsize=title_fontsize, fontweight=axis_fontweight)
plt.xlabel("Year",fontsize=label_fontsize, fontweight=axis_fontweight)
plt.ylabel("Average Sunspot Number (Ra)",fontsize=label_fontsize, fontweight=axis_fontweight)
plt.xticks(fontsize=ticks_fontsize, fontweight=axis_fontweight)
plt.yticks(fontsize=ticks_fontsize, fontweight=axis_fontweight)

plt.grid(True)
plt.show()

# %%
sunspot['Year'].unique()
# Out:
# array([1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954,
#        1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#        1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#        1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022, 2023, 2024], dtype=int64)

# %%
print(sunspot[sunspot['Year']==1945])
# Out:
#     Year  Month    Ra
# 1   1945      1  18.5
# 2   1945      2  11.8
# 3   1945      3  19.7
# 4   1945      4  31.6
# 5   1945      5  26.6
# 6   1945      6  37.3
# 7   1945      7  37.4
# 8   1945      8  24.6
# 9   1945      9  34.0
# 10  1945     10  71.3
# 11  1945     11  46.3
# 12  1945     12  28.4

# %%
years_drop = [1944,1945, 1946, 1947, 1948, 1949, 1950 , 1951, 1952 , 1953]
sunspot = sunspot[~(sunspot['Year'].isin(years_drop))]

# %%
sunspot
# Out:
#      Year  Month     Ra
# 109  1954      1    0.1
# 110  1954      2    0.3
# 111  1954      3    8.0
# 112  1954      4    0.6
# 113  1954      5    0.2
# ..    ...    ...    ...
# 949  2024      1  102.8
# 950  2024      2   94.8
# 951  2024      3   84.8
# 952  2024      4  107.1
# 953  2024      5  120.5
#
# [845 rows x 3 columns]

# %%
sunspot.isnull().sum()
# Out:
# Year     0
# Month    0
# Ra       0
# dtype: int64

# %%
sunspot
# Out:
#      Year  Month     Ra
# 109  1954      1    0.1
# 110  1954      2    0.3
# 111  1954      3    8.0
# 112  1954      4    0.6
# 113  1954      5    0.2
# ..    ...    ...    ...
# 949  2024      1  102.8
# 950  2024      2   94.8
# 951  2024      3   84.8
# 952  2024      4  107.1
# 953  2024      5  120.5
#
# [845 rows x 3 columns]

# %%
sunspot.to_csv("Number_of_sunspot.csv", index = False)

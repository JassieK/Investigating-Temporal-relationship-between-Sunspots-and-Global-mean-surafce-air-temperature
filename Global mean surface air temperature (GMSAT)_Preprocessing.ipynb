# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Atm = pd.read_csv("GLB.csv")

# %%
Atm
# Out:
#      Year   Jan   Feb   Mar   Apr   May    Jun    Jul    Aug    Sep    Oct  \
# 0    1880 -0.18 -0.24 -0.08 -0.15 -0.09   -0.2  -0.17  -0.09  -0.13  -0.22
# 1    1881 -0.19 -0.14  0.04  0.06  0.07  -0.19      0  -0.03  -0.15  -0.22
# 2    1882  0.16  0.14  0.05 -0.16 -0.14  -0.23  -0.16  -0.07  -0.14  -0.23
# 3    1883 -0.29 -0.37 -0.12 -0.18 -0.17  -0.08  -0.06  -0.14  -0.21  -0.11
# 4    1884 -0.13 -0.08 -0.36 -0.40 -0.34  -0.35  -0.31  -0.28  -0.27  -0.25
# ..    ...   ...   ...   ...   ...   ...    ...    ...    ...    ...    ...
# 140  2020  1.17  1.24  1.17  1.13  1.01   0.92    0.9   0.87   0.98   0.88
# 141  2021  0.81  0.65  0.89  0.76  0.79   0.85   0.92   0.82   0.93   0.99
# 142  2022  0.92  0.90  1.05  0.84  0.84   0.93   0.94   0.95   0.89   0.97
# 143  2023  0.88  0.98  1.22  1.00  0.94   1.08   1.19    1.2   1.48   1.34
# 144  2024  1.23  1.44  1.41  1.33  1.14    ***    ***    ***    ***    ***
#
#        Nov    Dec    J-D    D-N    DJF   MAM    JJA    SON
# ...

# %%
# Visualize the yearly data
plt.figure(figsize=(12, 8))
sns.lineplot(data=Atm.set_index('Year').dropna(), markers=True)
plt.title('Global Temperature Anomalies (1880-Present)')
plt.ylabel('Temperature Anomaly (°C)')
plt.xlabel('Year')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="Months")
plt.grid(True)
plt.show()

# %%
Atm = Atm.drop(columns=['J-D', 'D-N', 'DJF', 'MAM', 'JJA', 'SON'])

# %%
Atm
# Out:
#      Year   Jan   Feb   Mar   Apr   May    Jun    Jul    Aug    Sep    Oct  \
# 0    1880 -0.18 -0.24 -0.08 -0.15 -0.09   -0.2  -0.17  -0.09  -0.13  -0.22
# 1    1881 -0.19 -0.14  0.04  0.06  0.07  -0.19      0  -0.03  -0.15  -0.22
# 2    1882  0.16  0.14  0.05 -0.16 -0.14  -0.23  -0.16  -0.07  -0.14  -0.23
# 3    1883 -0.29 -0.37 -0.12 -0.18 -0.17  -0.08  -0.06  -0.14  -0.21  -0.11
# 4    1884 -0.13 -0.08 -0.36 -0.40 -0.34  -0.35  -0.31  -0.28  -0.27  -0.25
# ..    ...   ...   ...   ...   ...   ...    ...    ...    ...    ...    ...
# 140  2020  1.17  1.24  1.17  1.13  1.01   0.92    0.9   0.87   0.98   0.88
# 141  2021  0.81  0.65  0.89  0.76  0.79   0.85   0.92   0.82   0.93   0.99
# 142  2022  0.92  0.90  1.05  0.84  0.84   0.93   0.94   0.95   0.89   0.97
# 143  2023  0.88  0.98  1.22  1.00  0.94   1.08   1.19    1.2   1.48   1.34
# 144  2024  1.23  1.44  1.41  1.33  1.14    ***    ***    ***    ***    ***
#
#        Nov    Dec
# 0     -0.2  -0.17
# 1    -0.18  -0.06
# ...

# %%
# Visualize the yearly data
plt.figure(figsize=(12, 8))
sns.lineplot(data=Atm.set_index('Year').dropna(), markers=True)
plt.title('Global Temperature Anomalies (1880-Present)')
plt.ylabel('Temperature Anomaly (°C)')
plt.xlabel('Year')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="Months")
plt.grid(True)
plt.show()

# %%
# Unpivot the DataFrame
df_melted = pd.melt(Atm, id_vars=['Year'], var_name='Month', value_name='Value')

# Display the transformed DataFrame
print(df_melted)
# Out:
#       Year Month Value
# 0     1880   Jan -0.18
# 1     1881   Jan -0.19
# 2     1882   Jan  0.16
# 3     1883   Jan -0.29
# 4     1884   Jan -0.13
# ...    ...   ...   ...
# 1735  2020   Dec   0.8
# 1736  2021   Dec  0.87
# 1737  2022   Dec  0.81
# 1738  2023   Dec  1.36
# 1739  2024   Dec   ***
#
# [1740 rows x 3 columns]

# %%
# Sort the data by the 'Year' column in ascending order
sorted_data = df_melted.sort_values(by='Year', ascending=True)

# %%
sorted_data
# Out:
#       Year Month  Value
# 0     1880   Jan  -0.18
# 1450  1880   Nov   -0.2
# 1305  1880   Oct  -0.22
# 1160  1880   Sep  -0.13
# 1015  1880   Aug  -0.09
# ...    ...   ...    ...
# 434   2024   Mar   1.41
# 289   2024   Feb   1.44
# 144   2024   Jan   1.23
# 1594  2024   Nov    ***
# 1739  2024   Dec    ***
#
# [1740 rows x 3 columns]

# %%
# Define custom sorting order for months
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Convert the 'Month' column to a categorical type with the defined order
df_melted['Month'] = pd.Categorical(df_melted['Month'], categories=month_order, ordered=True)

# Sort the data by 'Year' and then by 'Month'
sorted_data = df_melted.sort_values(by=['Year', 'Month'])

# %%
sorted_data
# Out:
#       Year Month Value
# 0     1880   Jan -0.18
# 145   1880   Feb -0.24
# 290   1880   Mar -0.08
# 435   1880   Apr -0.15
# 580   1880   May -0.09
# ...    ...   ...   ...
# 1159  2024   Aug   ***
# 1304  2024   Sep   ***
# 1449  2024   Oct   ***
# 1594  2024   Nov   ***
# 1739  2024   Dec   ***
#
# [1740 rows x 3 columns]

# %%
sorted_data.isnull().sum()
# Out:
# Year     0
# Month    0
# Value    0
# dtype: int64

# %%
years_drop = range(1880,1954)
sorted_data = sorted_data[ ~sorted_data['Year'].isin(years_drop)]

# %%
sorted_data
# Out:
#       Year Month Value
# 74    1954   Jan -0.24
# 219   1954   Feb  -0.1
# 364   1954   Mar -0.15
# 509   1954   Apr -0.14
# 654   1954   May  -0.2
# ...    ...   ...   ...
# 1159  2024   Aug   ***
# 1304  2024   Sep   ***
# 1449  2024   Oct   ***
# 1594  2024   Nov   ***
# 1739  2024   Dec   ***
#
# [852 rows x 3 columns]

# %%
sorted_data.to_csv("air_temp.csv", index = False)
